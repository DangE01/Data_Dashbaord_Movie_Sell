# %% [markdown]
# # Data Dashboard for Movies sells

# %% [markdown]
# ## Cloning the repository

# %%
# !git clone https://github.com/DangE01/Data_Dashbaord_Movie_Sell.git
# Out:
# Cloning into 'Data_Dashbaord_Movie_Sell'...
# ...
