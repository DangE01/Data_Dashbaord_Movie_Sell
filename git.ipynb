# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cd gdrive/My Drive/
# %cd DSBA_6276
# Out:
# /content/gdrive/My Drive
# /content/gdrive/My Drive/DSBA_6276

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/My Drive/DSBA_6276/.git/

# %%
# !git remote add origin https://DangE01:Iluvit971382!@github.com/DangE01/Data_Dashbaord_Movie_Sell.git
# !git remote -v
# Out:
# origin	https://DangE01:Iluvit971382!@github.com/DangE01/Data_Dashbaord_Movie_Sell.git (fetch)
# origin	https://DangE01:Iluvit971382!@github.com/DangE01/Data_Dashbaord_Movie_Sell.git (push)

# %%
# !git config --global user.email 'elvisdangg@gmail.com'
# !git config --global user.name 'DangE01'

# %%
# !git add .

# !git commit -m 'First Visuals'
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git push origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.55 KiB | 264.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/DangE01/Data_Dashbaord_Movie_Sell.git
#  * [new branch]      master -> master
